# %%
import pandas as pd
import plotly.express as px
patient_notes = pd.read_csv("patient_notes.csv")
all_notes = []
all_notes_len = []

# %%
for notes in patient_notes['pn_history']:
    all_notes.append(notes)
    all_notes_len.append(len(notes))
fig = px.histogram(x = all_notes_len,  marginal="violin",nbins = 100)
fig.update_layout(template="plotly_white")
fig.update_xaxes(title = "Length of patient Notes")
fig.show()

# %%
conda install -c conda-forge wordcloud
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import wordcloud
wordcloud_notes = wordcloud.WordCloud(stopwords=wordcloud.STOPWORDS, max_font_size=120, max_words=5000, width = 600, height = 400, background_color='white').generate(" ".join(all_notes))
fig, ax = plt.subplots(figsize=(14,10))
ax.set_axis_off()
plt.imshow(wordcloud_notes)
